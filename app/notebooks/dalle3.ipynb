# %%
import os
from openai import OpenAI

openai_client = OpenAI(
    api_key=os.getenv("OPENAI_API_KEY"),
)

response =openai_client.images.generate(
    model="dall-e-2",
    size="1024x1024",
    quality="hd",
    n=5,
    # prompt="Make an interesting image of a avocado toast that is practical to cook for kids. ",
    # prompt="Make different variations of chocolate pancakes with exotic animals."
    prompt="Make different variations of chocolate pancakes with vehicles."
)

# %%
import requests
from PIL import Image
from io import BytesIO
# response_url = [requests.get(data.url) for data in response.data]
# imgs = [Image.open(BytesIO(url.content)) for url in response_url]
# imgs
response_url = requests.get(response.data[2].url)
imgs = Image.open(BytesIO(response_url.content))
imgs
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=1024x1024>
